# %%
import pandas as pd
import unidecode as unidecode

# %%
df_2022 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/971e0228-fa9c-4a42-b360-c842b29d2f56/download/acidentes2022.csv", delimiter=";")

# %%
# permitir que todas as colunas dessa base sejam visualizadas
pd.set_option('display.max_columns', None)

#leitura da base de 2019
df_2022.head()

# %%
df_2022.info()

# %%
colunas_selecionadas_2022 = ['data', 'hora', 'natureza', 'situacao', 'bairro', 'tipo', 'auto', 'moto', 'ciclom', 'ciclista', 'pedestre', 'onibus', 'caminhao', 'viatura', 'outros', 'vitimas', 'acidente_verificado', 'tempo_clima', 'sinalizacao', 'condicao_via', 'conservacao_via', 'mao_direcao']
df_2022_sot = df_2022[colunas_selecionadas_2022]

# %%
df_2022_sot.isnull().sum()

# %%
unique_types_2022 = df_2022_sot.applymap(type).nunique()

mixed_type_columns_2022 = unique_types_2022[unique_types_2022 >1].index
print(mixed_type_columns_2022)
# Out:
# Index(['bairro', 'tipo', 'acidente_verificado', 'tempo_clima', 'sinalizacao',
#        'condicao_via', 'conservacao_via', 'mao_direcao'],
#       dtype='object')

# %%
valores_nulos_2022 = {"bairro":'OUTROS', "tipo":'OUTROS', "tempo_clima":'OUTROS', "sinalizacao":'OUTROS', "condicao_via":'Outros',"conservacao_via":'OUTROS',"mao_direcao":'OUTROS', "acidente_verificado":'Outros'}

df_2022_sot = df_2022_sot.fillna(valores_nulos_2022)

# %%
str_columns_2022 = ['hora', 'natureza', 'situacao', 'bairro', 'tipo', 'tempo_clima', 'condicao_via', 'conservacao_via', 'mao_direcao']

df_2022_sot[str_columns_2022] = df_2022_sot[str_columns_2022].astype(str).apply(lambda x: x.str.upper())

# %%
# Lista de colunas que você deseja converter para inteiros
int_columns_2022 = ['auto', 'moto', 'ciclom', 'ciclista', 'pedestre', 'onibus', 'caminhao', 'viatura', 'outros', 'vitimas']

# Substituir vírgulas por pontos e converter para float
df_2022_sot[int_columns_2022] = df_2022_sot[int_columns_2022].replace(',', '.', regex=True).astype(float)

# Converter para inteiros
df_2022_sot[int_columns_2022] = df_2022_sot[int_columns_2022].fillna(0).astype(int)

# %%
df_2022_sot['data'] = pd.to_datetime(df_2022_sot['data'])

# %%
df_2022_sot['acidente_verificado'] = df_2022_sot['acidente_verificado'].replace('Não informado', 'OUTROS')

# %%
df_2022_sot = df_2022_sot.rename(columns={'natureza': 'natureza_acidente'})

# %%
df_2022_sot.columns = df_2022_sot.columns.str.upper()

# %%
df_2022_sot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2669 entries, 0 to 2668
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATA                 2669 non-null   datetime64[ns]
#  1   HORA                 2669 non-null   object
#  2   NATUREZA_ACIDENTE    2669 non-null   object
#  3   SITUACAO             2669 non-null   object
#  4   BAIRRO               2669 non-null   object
#  5   TIPO                 2669 non-null   object
#  6   AUTO                 2669 non-null   int32
#  7   MOTO                 2669 non-null   int32
#  8   CICLOM               2669 non-null   int32
#  9   CICLISTA             2669 non-null   int32
#  10  PEDESTRE             2669 non-null   int32
#  11  ONIBUS               2669 non-null   int32
#  12  CAMINHAO             2669 non-null   int32
#  13  VIATURA              2669 non-null   int32
#  14  OUTROS               2669 non-null   int32
#  15  VITIMAS              2669 non-null   int32
#  16  ACIDENTE_VERIFICADO  2669 non-null   object
#  17  TEMPO_CLIMA          2669 non-null   object
#  18  SINALIZACAO          2669 non-null   object
#  19  CONDICAO_VIA         2669 non-null   object
#  20  CONSERVACAO_VIA      2669 non-null   object
#  21  MAO_DIRECAO          2669 non-null   object
# dtypes: datetime64[ns](1), int32(10), object(11)
# memory usage: 354.6+ KB

# %%
# Listar todos os valores únicos para todas as colunas
for column in df_2022_sot.columns:
    unique_values = df_2022_sot[column].unique()
    
    print(f"Coluna: {column}")
    for value in unique_values:
        print(f"  Valor Único: {value}")
    print()
# Out:
# Coluna: DATA
#   Valor Único: 2022-01-01T00:00:00.000000000
#   Valor Único: 2022-01-02T00:00:00.000000000
#   Valor Único: 2022-01-03T00:00:00.000000000
#   Valor Único: 2022-01-04T00:00:00.000000000
#   Valor Único: 2022-01-05T00:00:00.000000000
#   Valor Único: 2022-01-06T00:00:00.000000000
#   Valor Único: 2022-01-07T00:00:00.000000000
#   Valor Único: 2022-01-08T00:00:00.000000000
#   Valor Único: 2022-01-09T00:00:00.000000000
#   Valor Único: 2022-01-10T00:00:00.000000000
#   Valor Único: 2022-01-11T00:00:00.000000000
#   Valor Único: 2022-01-12T00:00:00.000000000
#   Valor Único: 2022-01-13T00:00:00.000000000
#   Valor Único: 2022-01-14T00:00:00.000000000
#   Valor Único: 2022-01-15T00:00:00.000000000
#   Valor Único: 2022-01-16T00:00:00.000000000
#   Valor Único: 2022-01-17T00:00:00.000000000
#   Valor Único: 2022-01-18T00:00:00.000000000
#   Valor Único: 2022-01-19T00:00:00.000000000
#   Valor Único: 2022-01-20T00:00:00.000000000
#   Valor Único: 2022-01-21T00:00:00.000000000
#   Valor Único: 2022-01-22T00:00:00.000000000
#   Valor Único: 2022-01-23T00:00:00.000000000
#   Valor Único: 2022-01-24T00:00:00.000000000
#   Valor Único: 2022-01-25T00:00:00.000000000
#   Valor Único: 2022-01-26T00:00:00.000000000
#   Valor Único: 2022-01-27T00:00:00.000000000
#   Valor Único: 2022-01-28T00:00:00.000000000
#   Valor Único: 2022-01-29T00:00:00.000000000
#   Valor Único: 2022-01-30T00:00:00.000000000
#   Valor Único: 2022-01-31T00:00:00.000000000
#   Valor Único: 2022-02-01T00:00:00.000000000
#   Valor Único: 2022-02-02T00:00:00.000000000
#   Valor Único: 2022-02-03T00:00:00.000000000
#   Valor Único: 2022-02-04T00:00:00.000000000
#   Valor Único: 2022-02-06T00:00:00.000000000
#   Valor Único: 2022-02-07T00:00:00.000000000
#   Valor Único: 2022-02-08T00:00:00.000000000
#   Valor Único: 2022-02-09T00:00:00.000000000
#   Valor Único: 2022-02-10T00:00:00.000000000
#   Valor Único: 2022-02-11T00:00:00.000000000
#   Valor Único: 2022-02-12T00:00:00.000000000
#   Valor Único: 2022-02-13T00:00:00.000000000
#   Valor Único: 2022-02-14T00:00:00.000000000
#   Valor Único: 2022-02-15T00:00:00.000000000
#   Valor Único: 2022-02-16T00:00:00.000000000
#   Valor Único: 2022-02-17T00:00:00.000000000
#   Valor Único: 2022-02-18T00:00:00.000000000
#   Valor Único: 2022-02-19T00:00:00.000000000
#   Valor Único: 2022-02-20T00:00:00.000000000
#   Valor Único: 2022-02-21T00:00:00.000000000
#   Valor Único: 2022-02-22T00:00:00.000000000
#   Valor Único: 2022-02-23T00:00:00.000000000
#   Valor Único: 2022-02-24T00:00:00.000000000
#   Valor Único: 2022-02-25T00:00:00.000000000
#   Valor Único: 2022-02-26T00:00:00.000000000
#   Valor Único: 2022-02-28T00:00:00.000000000
#   Valor Único: 2022-03-01T00:00:00.000000000
#   Valor Único: 2022-03-02T00:00:00.000000000
#   Valor Único: 2022-03-03T00:00:00.000000000
#   Valor Único: 2022-03-04T00:00:00.000000000
#   Valor Único: 2022-03-05T00:00:00.000000000
#   Valor Único: 2022-03-06T00:00:00.000000000
#   Valor Único: 2022-03-07T00:00:00.000000000
#   Valor Único: 2022-03-08T00:00:00.000000000
#   Valor Único: 2022-03-09T00:00:00.000000000
#   Valor Único: 2022-03-10T00:00:00.000000000
#   Valor Único: 2022-03-11T00:00:00.000000000
#   Valor Único: 2022-03-12T00:00:00.000000000
#   Valor Único: 2022-03-13T00:00:00.000000000
#   Valor Único: 2022-03-14T00:00:00.000000000
#   Valor Único: 2022-03-15T00:00:00.000000000
#   Valor Único: 2022-03-16T00:00:00.000000000
#   Valor Único: 2022-03-17T00:00:00.000000000
#   Valor Único: 2022-03-18T00:00:00.000000000
#   Valor Único: 2022-03-19T00:00:00.000000000
#   Valor Único: 2022-03-20T00:00:00.000000000
#   Valor Único: 2022-03-21T00:00:00.000000000
#   Valor Único: 2022-03-22T00:00:00.000000000
#   Valor Único: 2022-03-23T00:00:00.000000000
#   Valor Único: 2022-03-24T00:00:00.000000000
#   Valor Único: 2022-03-25T00:00:00.000000000
#   Valor Único: 2022-03-26T00:00:00.000000000
#   Valor Único: 2022-03-27T00:00:00.000000000
#   Valor Único: 2022-03-28T00:00:00.000000000
#   Valor Único: 2022-03-29T00:00:00.000000000
#   Valor Único: 2022-03-30T00:00:00.000000000
#   Valor Único: 2022-03-31T00:00:00.000000000
#   Valor Único: 2022-04-01T00:00:00.000000000
#   Valor Único: 2022-04-02T00:00:00.000000000
#   Valor Único: 2022-04-03T00:00:00.000000000
#   Valor Único: 2022-04-04T00:00:00.000000000
#   Valor Único: 2022-04-05T00:00:00.000000000
#   Valor Único: 2022-04-06T00:00:00.000000000
#   Valor Único: 2022-04-07T00:00:00.000000000
#   Valor Único: 2022-04-08T00:00:00.000000000
#   Valor Único: 2022-04-09T00:00:00.000000000
#   Valor Único: 2022-04-10T00:00:00.000000000
#   Valor Único: 2022-04-11T00:00:00.000000000
#   Valor Único: 2022-04-12T00:00:00.000000000
#   Valor Único: 2022-04-13T00:00:00.000000000
#   Valor Único: 2022-04-14T00:00:00.000000000
#   Valor Único: 2022-04-15T00:00:00.000000000
#   Valor Único: 2022-04-16T00:00:00.000000000
#   Valor Único: 2022-04-17T00:00:00.000000000
#   Valor Único: 2022-04-18T00:00:00.000000000
#   Valor Único: 2022-04-19T00:00:00.000000000
#   Valor Único: 2022-04-20T00:00:00.000000000
#   Valor Único: 2022-04-21T00:00:00.000000000
#   Valor Único: 2022-04-22T00:00:00.000000000
#   Valor Único: 2022-04-23T00:00:00.000000000
#   Valor Único: 2022-04-24T00:00:00.000000000
#   Valor Único: 2022-04-25T00:00:00.000000000
#   Valor Único: 2022-04-26T00:00:00.000000000
#   Valor Único: 2022-04-27T00:00:00.000000000
#   Valor Único: 2022-04-28T00:00:00.000000000
#   Valor Único: 2022-04-29T00:00:00.000000000
#   Valor Único: 2022-04-30T00:00:00.000000000
#   Valor Único: 2022-05-01T00:00:00.000000000
#   Valor Único: 2022-05-02T00:00:00.000000000
#   Valor Único: 2022-05-03T00:00:00.000000000
#   Valor Único: 2022-05-04T00:00:00.000000000
#   Valor Único: 2022-05-05T00:00:00.000000000
#   Valor Único: 2022-05-06T00:00:00.000000000
#   Valor Único: 2022-05-07T00:00:00.000000000
#   Valor Único: 2022-05-08T00:00:00.000000000
#   Valor Único: 2022-05-09T00:00:00.000000000
#   Valor Único: 2022-05-10T00:00:00.000000000
#   Valor Único: 2022-05-11T00:00:00.000000000
#   Valor Único: 2022-05-12T00:00:00.000000000
#   Valor Único: 2022-05-13T00:00:00.000000000
#   Valor Único: 2022-05-14T00:00:00.000000000
#   Valor Único: 2022-05-15T00:00:00.000000000
#   Valor Único: 2022-05-16T00:00:00.000000000
#   Valor Único: 2022-05-17T00:00:00.000000000
#   Valor Único: 2022-05-18T00:00:00.000000000
#   Valor Único: 2022-05-19T00:00:00.000000000
#   Valor Único: 2022-05-20T00:00:00.000000000
#   Valor Único: 2022-05-21T00:00:00.000000000
#   Valor Único: 2022-05-22T00:00:00.000000000
#   Valor Único: 2022-05-23T00:00:00.000000000
#   Valor Único: 2022-05-24T00:00:00.000000000
#   Valor Único: 2022-05-25T00:00:00.000000000
#   Valor Único: 2022-05-26T00:00:00.000000000
#   Valor Único: 2022-05-27T00:00:00.000000000
#   Valor Único: 2022-05-30T00:00:00.000000000
#   Valor Único: 2022-05-31T00:00:00.000000000
#   Valor Único: 2022-06-01T00:00:00.000000000
#   Valor Único: 2022-06-02T00:00:00.000000000
#   Valor Único: 2022-06-03T00:00:00.000000000
#   Valor Único: 2022-06-04T00:00:00.000000000
#   Valor Único: 2022-06-05T00:00:00.000000000
#   Valor Único: 2022-06-06T00:00:00.000000000
#   Valor Único: 2022-06-07T00:00:00.000000000
#   Valor Único: 2022-06-08T00:00:00.000000000
#   Valor Único: 2022-06-09T00:00:00.000000000
#   Valor Único: 2022-06-10T00:00:00.000000000
#   Valor Único: 2022-06-11T00:00:00.000000000
#   Valor Único: 2022-06-12T00:00:00.000000000
#   Valor Único: 2022-06-13T00:00:00.000000000
#   Valor Único: 2022-06-14T00:00:00.000000000
#   Valor Único: 2022-06-15T00:00:00.000000000
#   Valor Único: 2022-06-16T00:00:00.000000000
#   Valor Único: 2022-06-17T00:00:00.000000000
#   Valor Único: 2022-06-18T00:00:00.000000000
#   Valor Único: 2022-06-19T00:00:00.000000000
#   Valor Único: 2022-06-20T00:00:00.000000000
#   Valor Único: 2022-06-21T00:00:00.000000000
#   Valor Único: 2022-06-22T00:00:00.000000000
#   Valor Único: 2022-06-23T00:00:00.000000000
#   Valor Único: 2022-06-24T00:00:00.000000000
#   Valor Único: 2022-06-25T00:00:00.000000000
#   Valor Único: 2022-06-26T00:00:00.000000000
#   Valor Único: 2022-06-27T00:00:00.000000000
#   Valor Único: 2022-06-28T00:00:00.000000000
#   Valor Único: 2022-06-29T00:00:00.000000000
#   Valor Único: 2022-06-30T00:00:00.000000000
#   Valor Único: 2022-07-01T00:00:00.000000000
#   Valor Único: 2022-07-02T00:00:00.000000000
#   Valor Único: 2022-07-03T00:00:00.000000000
#   Valor Único: 2022-07-04T00:00:00.000000000
#   Valor Único: 2022-07-05T00:00:00.000000000
#   Valor Único: 2022-07-06T00:00:00.000000000
#   Valor Único: 2022-07-07T00:00:00.000000000
#   Valor Único: 2022-07-08T00:00:00.000000000
#   Valor Único: 2022-07-09T00:00:00.000000000
#   Valor Único: 2022-07-10T00:00:00.000000000
#   Valor Único: 2022-07-11T00:00:00.000000000
#   Valor Único: 2022-07-12T00:00:00.000000000
#   Valor Único: 2022-07-13T00:00:00.000000000
#   Valor Único: 2022-07-14T00:00:00.000000000
#   Valor Único: 2022-07-15T00:00:00.000000000
#   Valor Único: 2022-07-16T00:00:00.000000000
#   Valor Único: 2022-07-17T00:00:00.000000000
#   Valor Único: 2022-07-18T00:00:00.000000000
#   Valor Único: 2022-07-19T00:00:00.000000000
#   Valor Único: 2022-07-20T00:00:00.000000000
#   Valor Único: 2022-07-21T00:00:00.000000000
#   Valor Único: 2022-07-22T00:00:00.000000000
#   Valor Único: 2022-07-23T00:00:00.000000000
#   Valor Único: 2022-07-24T00:00:00.000000000
#   Valor Único: 2022-07-25T00:00:00.000000000
#   Valor Único: 2022-07-26T00:00:00.000000000
#   Valor Único: 2022-07-27T00:00:00.000000000
#   Valor Único: 2022-07-28T00:00:00.000000000
#   Valor Único: 2022-07-29T00:00:00.000000000
#   Valor Único: 2022-07-30T00:00:00.000000000
#   Valor Único: 2022-07-31T00:00:00.000000000
#   Valor Único: 2022-08-01T00:00:00.000000000
#   Valor Único: 2022-08-02T00:00:00.000000000
#   Valor Único: 2022-08-03T00:00:00.000000000
#   Valor Único: 2022-08-04T00:00:00.000000000
#   Valor Único: 2022-08-05T00:00:00.000000000
#   Valor Único: 2022-08-06T00:00:00.000000000
#   Valor Único: 2022-08-07T00:00:00.000000000
#   Valor Único: 2022-08-08T00:00:00.000000000
#   Valor Único: 2022-08-09T00:00:00.000000000
#   Valor Único: 2022-08-10T00:00:00.000000000
#   Valor Único: 2022-08-11T00:00:00.000000000
#   Valor Único: 2022-08-12T00:00:00.000000000
#   Valor Único: 2022-08-13T00:00:00.000000000
#   Valor Único: 2022-08-14T00:00:00.000000000
#   Valor Único: 2022-08-15T00:00:00.000000000
#   Valor Único: 2022-08-16T00:00:00.000000000
#   Valor Único: 2022-08-17T00:00:00.000000000
#   Valor Único: 2022-08-18T00:00:00.000000000
#   Valor Único: 2022-08-19T00:00:00.000000000
#   Valor Único: 2022-08-20T00:00:00.000000000
#   Valor Único: 2022-08-21T00:00:00.000000000
#   Valor Único: 2022-08-22T00:00:00.000000000
#   Valor Único: 2022-08-23T00:00:00.000000000
#   Valor Único: 2022-08-24T00:00:00.000000000
#   Valor Único: 2022-08-25T00:00:00.000000000
#   Valor Único: 2022-08-26T00:00:00.000000000
#   Valor Único: 2022-08-27T00:00:00.000000000
#   Valor Único: 2022-08-28T00:00:00.000000000
#   Valor Único: 2022-08-29T00:00:00.000000000
#   Valor Único: 2022-08-30T00:00:00.000000000
#   Valor Único: 2022-08-31T00:00:00.000000000
#   Valor Único: 2022-09-01T00:00:00.000000000
#   Valor Único: 2022-09-02T00:00:00.000000000
#   Valor Único: 2022-09-03T00:00:00.000000000
#   Valor Único: 2022-09-04T00:00:00.000000000
#   Valor Único: 2022-09-05T00:00:00.000000000
#   Valor Único: 2022-09-06T00:00:00.000000000
#   Valor Único: 2022-09-07T00:00:00.000000000
#   Valor Único: 2022-09-08T00:00:00.000000000
#   Valor Único: 2022-09-09T00:00:00.000000000
#   Valor Único: 2022-09-10T00:00:00.000000000
#   Valor Único: 2022-09-11T00:00:00.000000000
#   Valor Único: 2022-09-12T00:00:00.000000000
#   Valor Único: 2022-09-13T00:00:00.000000000
#   Valor Único: 2022-09-14T00:00:00.000000000
#   Valor Único: 2022-09-15T00:00:00.000000000
#   Valor Único: 2022-09-16T00:00:00.000000000
#   Valor Único: 2022-09-17T00:00:00.000000000
#   Valor Único: 2022-09-18T00:00:00.000000000
#   Valor Único: 2022-09-19T00:00:00.000000000
#   Valor Único: 2022-09-20T00:00:00.000000000
#   Valor Único: 2022-09-21T00:00:00.000000000
#   Valor Único: 2022-09-22T00:00:00.000000000
#   Valor Único: 2022-09-23T00:00:00.000000000
#   Valor Único: 2022-09-24T00:00:00.000000000
#   Valor Único: 2022-09-25T00:00:00.000000000
#   Valor Único: 2022-09-26T00:00:00.000000000
#   Valor Único: 2022-09-27T00:00:00.000000000
#   Valor Único: 2022-09-28T00:00:00.000000000
#   Valor Único: 2022-09-29T00:00:00.000000000
#   Valor Único: 2022-09-30T00:00:00.000000000
#   Valor Único: 2022-10-01T00:00:00.000000000
#   Valor Único: 2022-10-02T00:00:00.000000000
#   Valor Único: 2022-10-03T00:00:00.000000000
#   Valor Único: 2022-10-04T00:00:00.000000000
#   Valor Único: 2022-10-05T00:00:00.000000000
#   Valor Único: 2022-10-06T00:00:00.000000000
#   Valor Único: 2022-10-07T00:00:00.000000000
#   Valor Único: 2022-10-08T00:00:00.000000000
#   Valor Único: 2022-10-09T00:00:00.000000000
#   Valor Único: 2022-10-10T00:00:00.000000000
#   Valor Único: 2022-10-11T00:00:00.000000000
#   Valor Único: 2022-10-12T00:00:00.000000000
#   Valor Único: 2022-10-13T00:00:00.000000000
#   Valor Único: 2022-10-14T00:00:00.000000000
#   Valor Único: 2022-10-15T00:00:00.000000000
#   Valor Único: 2022-10-16T00:00:00.000000000
#   Valor Único: 2022-10-17T00:00:00.000000000
#   Valor Único: 2022-10-18T00:00:00.000000000
#   Valor Único: 2022-10-19T00:00:00.000000000
#   Valor Único: 2022-10-20T00:00:00.000000000
#   Valor Único: 2022-10-21T00:00:00.000000000
#   Valor Único: 2022-10-22T00:00:00.000000000
#   Valor Único: 2022-10-23T00:00:00.000000000
#   Valor Único: 2022-10-24T00:00:00.000000000
#   Valor Único: 2022-10-25T00:00:00.000000000
#   Valor Único: 2022-10-26T00:00:00.000000000
#   Valor Único: 2022-10-27T00:00:00.000000000
#   Valor Único: 2022-10-28T00:00:00.000000000
#   Valor Único: 2022-10-29T00:00:00.000000000
#   Valor Único: 2022-10-30T00:00:00.000000000
#   Valor Único: 2022-10-31T00:00:00.000000000
#   Valor Único: 2022-11-01T00:00:00.000000000
#   Valor Único: 2022-11-02T00:00:00.000000000
#   Valor Único: 2022-11-03T00:00:00.000000000
#   Valor Único: 2022-11-04T00:00:00.000000000
#   Valor Único: 2022-11-05T00:00:00.000000000
#   Valor Único: 2022-11-06T00:00:00.000000000
#   Valor Único: 2022-11-07T00:00:00.000000000
#   Valor Único: 2022-11-08T00:00:00.000000000
#   Valor Único: 2022-11-09T00:00:00.000000000
#   Valor Único: 2022-11-10T00:00:00.000000000
#   Valor Único: 2022-11-11T00:00:00.000000000
#   Valor Único: 2022-11-12T00:00:00.000000000
#   Valor Único: 2022-11-13T00:00:00.000000000
#   Valor Único: 2022-11-14T00:00:00.000000000
#   Valor Único: 2022-11-15T00:00:00.000000000
#   Valor Único: 2022-11-16T00:00:00.000000000
#   Valor Único: 2022-11-17T00:00:00.000000000
#   Valor Único: 2022-11-18T00:00:00.000000000
#   Valor Único: 2022-11-19T00:00:00.000000000
#   Valor Único: 2022-11-20T00:00:00.000000000
#   Valor Único: 2022-11-21T00:00:00.000000000
#   Valor Único: 2022-11-22T00:00:00.000000000
#   Valor Único: 2022-11-23T00:00:00.000000000
#   Valor Único: 2022-11-24T00:00:00.000000000
#   Valor Único: 2022-11-25T00:00:00.000000000
#   Valor Único: 2022-11-26T00:00:00.000000000
#   Valor Único: 2022-11-27T00:00:00.000000000
#   Valor Único: 2022-11-28T00:00:00.000000000
#   Valor Único: 2022-11-29T00:00:00.000000000
#   Valor Único: 2022-11-30T00:00:00.000000000
#   Valor Único: 2022-12-01T00:00:00.000000000
#   Valor Único: 2022-12-02T00:00:00.000000000
#   Valor Único: 2022-12-03T00:00:00.000000000
#   Valor Único: 2022-12-04T00:00:00.000000000
#   Valor Único: 2022-12-05T00:00:00.000000000
#   Valor Único: 2022-12-06T00:00:00.000000000
#   Valor Único: 2022-12-07T00:00:00.000000000
#   Valor Único: 2022-12-08T00:00:00.000000000
#   Valor Único: 2022-12-09T00:00:00.000000000
#   Valor Único: 2022-12-10T00:00:00.000000000
#   Valor Único: 2022-12-11T00:00:00.000000000
#   Valor Único: 2022-12-12T00:00:00.000000000
#   Valor Único: 2022-12-13T00:00:00.000000000
#   Valor Único: 2022-12-14T00:00:00.000000000
#   Valor Único: 2022-12-15T00:00:00.000000000
#   Valor Único: 2022-12-16T00:00:00.000000000
#   Valor Único: 2022-12-17T00:00:00.000000000
#   Valor Único: 2022-12-18T00:00:00.000000000
#   Valor Único: 2022-12-19T00:00:00.000000000
#   Valor Único: 2022-12-20T00:00:00.000000000
#   Valor Único: 2022-12-21T00:00:00.000000000
#   Valor Único: 2022-12-22T00:00:00.000000000
#   Valor Único: 2022-12-23T00:00:00.000000000
#   Valor Único: 2022-12-24T00:00:00.000000000
#   Valor Único: 2022-12-25T00:00:00.000000000
#   Valor Único: 2022-12-26T00:00:00.000000000
#   Valor Único: 2022-12-27T00:00:00.000000000
#   Valor Único: 2022-12-28T00:00:00.000000000
#   Valor Único: 2022-12-29T00:00:00.000000000
#   Valor Único: 2022-12-30T00:00:00.000000000
#   Valor Único: 2022-12-31T00:00:00.000000000
#
# Coluna: HORA
#   Valor Único: NAN
#
# Coluna: NATUREZA_ACIDENTE
#   Valor Único: COM VÍTIMA
#   Valor Único: SEM VÍTIMA
#   Valor Único: VÍTIMA FATAL
#
# Coluna: SITUACAO
#   Valor Único: FINALIZADA
#   Valor Único: CANCELADA
#   Valor Único: DUPLICIDADE
#   Valor Único: DATA / HORA (PREENCHER)
#
# Coluna: BAIRRO
#   Valor Único: JORDÃO
#   Valor Único: IMBIRIBEIRA
#   Valor Único: CAXANGÁ
#   Valor Único: JOANA BEZERRA
#   Valor Único: AFLITOS
#   Valor Único: TAMARINEIRA
#   Valor Único: VASCO DA GAMA
#   Valor Único: ARRUDA
#   Valor Único: APIPUCOS
#   Valor Único: GRAÇAS
#   Valor Único: BOA VIAGEM
#   Valor Único: CASA AMARELA
#   Valor Único: ILHA DO LEITE
#   Valor Único: IPSEP
#   Valor Único: DOIS IRMÃOS
#   Valor Único: CABANGA
#   Valor Único: ESPINHEIRO
#   Valor Único: IBURA
#   Valor Único: ÁGUA FRIA
#   Valor Único: BAIRRO DO RECIFE
#   Valor Único: ILHA JOANA BEZERRA
#   Valor Único: NOVA DESCOBERTA
#   Valor Único: BARRO
#   Valor Único: CASA FORTE
#   Valor Único: SANTO ANTÔNIO
#   Valor Único: CORDEIRO
#   Valor Único: IPUTINGA
#   Valor Único: SANTO AMARO
#   Valor Único: DERBY
#   Valor Único: LINHA DO TIRO
#   Valor Único: BOA VISTA
#   Valor Único: AFOGADOS
#   Valor Único: PINA
#   Valor Único: ENCRUZILHADA
#   Valor Único: ALTO JOSÉ BONIFÁCIO
#   Valor Único: MACAXEIRA
#   Valor Único: MADALENA
#   Valor Único: VÁRZEA
#   Valor Único: SÃO JOSÉ
#   Valor Único: CAMPO GRANDE
#   Valor Único: PAISSANDU
#   Valor Único: AREIAS
#   Valor Único: PARNAMIRIM
#   Valor Único: BOMBA DO HEMETÉRIO
#   Valor Único: PRADO
#   Valor Único: ENGENHO DO MEIO
#   Valor Único: DOIS UNIDOS
#   Valor Único: TORRE
#   Valor Único: COHAB
#   Valor Único: ROSARINHO
#   Valor Único: BREJO DA GUABIRABA
#   Valor Único: CAJUEIRO
#   Valor Único: JAQUEIRA
#   Valor Único: SÍTIO DOS PINTOS
#   Valor Único: PORTO DA MADEIRA
#   Valor Único: JARDIM SÃO PAULO
#   Valor Único: BONGI
#   Valor Único: TORRÕES
#   Valor Único: TEJIPIÓ
#   Valor Único: BEBERIBE
#   Valor Único: SAN MARTIN
#   Valor Único: ILHA DO RETIRO
#   Valor Único: OUTROS
#   Valor Único: ALTO SANTA TERESINHA
#   Valor Único: CAMPINA DO BARRETO
#   Valor Único: TOTÓ
#   Valor Único: PASSARINHO
#   Valor Único: CURADO
#   Valor Único: MANGUEIRA
#   Valor Único: MANGABEIRA
#   Valor Único: GUABIRABA
#   Valor Único: ESTÂNCIA
#   Valor Único: MUSTARDINHA
#   Valor Único: ZUMBI
#   Valor Único: PONTO DE PARADA
#   Valor Único: TORREÃO
#   Valor Único: POÇO DA PANELA
#   Valor Único: FUNDÃO
#   Valor Único: COQUEIRAL
#   Valor Único: SANCHO
#   Valor Único: CIDADE UNIVERSITÁRIA
#   Valor Único: JIQUIÁ
#   Valor Único: ALTO DO MANDU
#   Valor Único: SOLEDADE
#   Valor Único: COELHOS
#   Valor Único: MONTEIRO
#   Valor Único: HIPÓDROMO
#   Valor Único: MORRO DA CONCEIÇÃO
#   Valor Único: SANTANA
#   Valor Único: BRASÍLIA TEIMOSA
#   Valor Único: CÓRREGO DO JENIPAPO
#   Valor Único: ALTO JOSÉ DO PINHO
#
# Coluna: TIPO
#   Valor Único: COLISÃO FRONTAL
#   Valor Único: COLISÃO TRASEIRA
#   Valor Único: COLISÃO LATERAL
#   Valor Único: CAPOTAMENTO
#   Valor Único: OUTROS
#   Valor Único: COLISÃO TRANSVERSAL
#   Valor Único: ATROPELAMENTO DE PESSOA
#   Valor Único: CHOQUE
#   Valor Único: COLISÃO COM CICLISTA
#   Valor Único: QUEDA
#   Valor Único: TOMBAMENTO
#   Valor Único: ATROPELAMENTO DE ANIMAL
#   Valor Único: ENGAVETAMENTO
#   Valor Único: RENDIÇÃO
#   Valor Único: PROTESTO
#   Valor Único: APOIO EMLURB
#   Valor Único: MONITORAMENTO
#   Valor Único: FISCALIZAÇÃO
#
# Coluna: AUTO
#   Valor Único: 1
#   Valor Único: 2
#   Valor Único: 0
#   Valor Único: 3
#   Valor Único: 5
#   Valor Único: 4
#   Valor Único: 7
#
# Coluna: MOTO
#   Valor Único: 1
#   Valor Único: 0
#   Valor Único: 2
#   Valor Único: 3
#
# Coluna: CICLOM
#   Valor Único: 0
#   Valor Único: 1
#
# Coluna: CICLISTA
#   Valor Único: 0
#   Valor Único: 1
#   Valor Único: 2
#
# Coluna: PEDESTRE
#   Valor Único: 0
#   Valor Único: 1
#   Valor Único: 2
#
# Coluna: ONIBUS
#   Valor Único: 0
#   Valor Único: 1
#   Valor Único: 2
#
# Coluna: CAMINHAO
#   Valor Único: 0
#   Valor Único: 1
#   Valor Único: 2
#
# Coluna: VIATURA
#   Valor Único: 0
#   Valor Único: 1
#   Valor Único: 2
#
# Coluna: OUTROS
#   Valor Único: 0
#   Valor Único: 1
#
# Coluna: VITIMAS
#   Valor Único: 1
#   Valor Único: 0
#   Valor Único: 2
#   Valor Único: 3
#   Valor Único: 8
#   Valor Único: 5
#   Valor Único: 7
#   Valor Único: 4
#
# Coluna: ACIDENTE_VERIFICADO
#   Valor Único: Longo da via
#   Valor Único: Outros
#   Valor Único: Cruzamento
#   Valor Único: Esquina
#   Valor Único: Viaduto
#   Valor Único: Rotatória
#   Valor Único: Ponte
#   Valor Único: OUTROS
#
# Coluna: TEMPO_CLIMA
#   Valor Único: BOM
#   Valor Único: OUTROS
#   Valor Único: CHUVOSO
#   Valor Único: NUBLADO
#
# Coluna: SINALIZACAO
#   Valor Único: Não existente
#   Valor Único: Perfeito estado
#   Valor Único: OUTROS
#   Valor Único: Incompleta
#   Valor Único: Ilegível
#
# Coluna: CONDICAO_VIA
#   Valor Único: SECA
#   Valor Único: OUTROS
#   Valor Único: MOLHADA
#   Valor Único: OLEOSA
#
# Coluna: CONSERVACAO_VIA
#   Valor Único: PERFEITO ESTADO
#   Valor Único: OUTROS
#   Valor Único: MAL CONSERVADA
#   Valor Único: MAL ILUMINADA
#
# Coluna: MAO_DIRECAO
#   Valor Único: DUPLA
#   Valor Único: OUTROS
#   Valor Único: ÚNICA
#   Valor Único: INGLESA
