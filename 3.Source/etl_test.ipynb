# %%
import pandas as pd

# %%
#df_2018 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/2485590a-3b35-4ad0-b955-8dfc36b61021/download/acidentes_2018.csv", delimiter=";")
df_2019 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/3531bafe-d47d-415e-b154-a881081ac76c/download/acidentes-2019.csv", delimiter=";")
df_2020 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/fc1c8460-0406-4fff-b51a-e79205d1f1ab/download/acidentes_2020-novo.csv", delimiter=";")
df_2021 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/2caa8f41-ccd9-4ea5-906d-f66017d6e107/download/acidentes2021.csv", delimiter=";")
df_2022 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/971e0228-fa9c-4a42-b360-c842b29d2f56/download/acidentes2022.csv", delimiter=";")

# %%
#Este comando exibirá as primeiras linhas do DataFrame 
df_2019.head()
# Out:
#          DATA      hora natureza_acidente    situacao       bairro  \
# 0  2019-01-01  00:41:00        SEM VÍTIMA  FINALIZADA        IPSEP
# 1  2019-01-01  01:37:00        SEM VÍTIMA  FINALIZADA   BOA VIAGEM
# 2  2019-01-01  14:20:00        SEM VÍTIMA   CANCELADA   BOA VIAGEM
# 3  2019-01-01  02:53:00        SEM VÍTIMA   CANCELADA  IMBIRIBEIRA
# 4  2019-01-01  08:17:00        COM VÍTIMA  FINALIZADA     JAQUEIRA
#
#                           endereco numero    detalhe_endereco_acidente  \
# 0                        AV RECIFE    NaN                          NaN
# 1       RUA PADRE BERNADINO PESSOA    NaN  RUA MINISTRO NELSON HUNGRIA
# 2  AV ENGENHEIRO DOMINGOS FERREIRA    NaN           RUA DOM JOSE LOPES
# 3            AV GENERAL MAC ARTHUR    100                     RUA JACY
# 4                   RUA TITO ROSAS     63                          NaN
#
#                                          complemento  \
# 0                             LADO OPOSTO AO Nº 3257
# 1                                                NaN
# 2  EM FRENTE A DELEGACIA DE BOA VIAGEM, LADO ESQU...
# 3                     EM FRENTE A ART LED ILUMINAÇÃO
# 4                            ED. JARDINS DA JAQUEIRA
#
#                endereco_cruzamento  ...      sinalizacao condicao_via  \
# 0                        AV RECIFE  ...  Perfeito estado         Seca
# 1       RUA PADRE BERNADINO PESSOA  ...  Perfeito estado         Seca
# 2  AV ENGENHEIRO DOMINGOS FERREIRA  ...              NaN          NaN
# 3            AV GENERAL MAC ARTHUR  ...              NaN          NaN
# 4                   RUA TITO ROSAS  ...  Perfeito estado         Seca
#
#    conservacao_via     ponto_controle situacao_placa velocidade_max_via  \
# 0  Perfeito estado         Não existe  Não há placas            60 km/h
# 1  Perfeito estado  Faixa de pedestre  Não há placas                NaN
# 2              NaN                NaN            NaN                NaN
# 3              NaN                NaN            NaN                NaN
# 4  Perfeito estado         Não existe  Não há placas            40 km/h
#
#   mao_direcao      divisao_via1  divisao_via2  divisao_via3
# 0       Única  Faixa seccionada           NaN           NaN
# 1       Única        Não existe           NaN           NaN
# 2         NaN               NaN           NaN           NaN
# 3         NaN               NaN           NaN           NaN
# 4       Única  Faixa seccionada           NaN           NaN
#
# [5 rows x 41 columns]

# %%
#Este comando fornece informações sobre os tipos de dados de cada coluna
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12062 entries, 0 to 12061
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DATA                       12062 non-null  object
#  1   hora                       12046 non-null  object
#  2   natureza_acidente          12058 non-null  object
#  3   situacao                   12058 non-null  object
#  4   bairro                     11914 non-null  object
#  5   endereco                   12009 non-null  object
#  6   numero                     6013 non-null   object
#  7   detalhe_endereco_acidente  4308 non-null   object
#  8   complemento                9609 non-null   object
#  9   endereco_cruzamento        12002 non-null  object
#  10  numero_cruzamento          6011 non-null   object
#  11  referencia_cruzamento      9606 non-null   object
#  12  bairro_cruzamento          11909 non-null  object
#  13  num_semaforo               3029 non-null   float64
#  14  sentido_via                8293 non-null   object
#  15  tipo                       12062 non-null  object
#  16  descricao                  11762 non-null  object
#  17  auto                       11140 non-null  float64
#  18  moto                       2904 non-null   float64
#  19  ciclom                     48 non-null     float64
#  20  ciclista                   224 non-null    float64
#  21  pedestre                   255 non-null    float64
#  22  onibus                     1811 non-null   float64
#  23  caminhao                   1224 non-null   float64
#  24  viatura                    122 non-null    float64
#  25  outros                     210 non-null    float64
#  26  vitimas                    12035 non-null  float64
#  27  vitimasfatais              25 non-null     float64
#  28  acidente_verificado        9191 non-null   object
#  29  tempo_clima                9706 non-null   object
#  30  situacao_semaforo          9581 non-null   object
#  31  sinalizacao                9524 non-null   object
#  32  condicao_via               9673 non-null   object
#  33  conservacao_via            9525 non-null   object
#  34  ponto_controle             8670 non-null   object
#  35  situacao_placa             8733 non-null   object
#  36  velocidade_max_via         2858 non-null   object
#  37  mao_direcao                9522 non-null   object
#  38  divisao_via1               9130 non-null   object
#  39  divisao_via2               908 non-null    object
#  40  divisao_via3               150 non-null    object
# dtypes: float64(12), object(29)
# memory usage: 3.8+ MB

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12062 entries, 0 to 12061
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DATA                       12062 non-null  object
#  1   hora                       12046 non-null  object
#  2   natureza_acidente          12058 non-null  object
#  3   situacao                   12058 non-null  object
#  4   bairro                     11914 non-null  object
#  5   endereco                   12009 non-null  object
#  6   numero                     6013 non-null   object
#  7   detalhe_endereco_acidente  4308 non-null   object
#  8   complemento                9609 non-null   object
#  9   endereco_cruzamento        12002 non-null  object
#  10  numero_cruzamento          6011 non-null   object
#  11  referencia_cruzamento      9606 non-null   object
#  12  bairro_cruzamento          11909 non-null  object
#  13  num_semaforo               3029 non-null   float64
#  14  sentido_via                8293 non-null   object
#  15  tipo                       12062 non-null  object
#  16  descricao                  11762 non-null  object
#  17  auto                       11140 non-null  float64
#  18  moto                       2904 non-null   float64
#  19  ciclom                     48 non-null     float64
#  20  ciclista                   224 non-null    float64
#  21  pedestre                   255 non-null    float64
#  22  onibus                     1811 non-null   float64
#  23  caminhao                   1224 non-null   float64
#  24  viatura                    122 non-null    float64
#  25  outros                     210 non-null    float64
#  26  vitimas                    12035 non-null  float64
#  27  vitimasfatais              25 non-null     float64
#  28  acidente_verificado        9191 non-null   object
#  29  tempo_clima                9706 non-null   object
#  30  situacao_semaforo          9581 non-null   object
#  31  sinalizacao                9524 non-null   object
#  32  condicao_via               9673 non-null   object
#  33  conservacao_via            9525 non-null   object
#  34  ponto_controle             8670 non-null   object
#  35  situacao_placa             8733 non-null   object
#  36  velocidade_max_via         2858 non-null   object
#  37  mao_direcao                9522 non-null   object
#  38  divisao_via1               9130 non-null   object
#  39  divisao_via2               908 non-null    object
#  40  divisao_via3               150 non-null    object
# dtypes: float64(12), object(29)
# memory usage: 3.8+ MB

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4092 entries, 0 to 4091
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   data                       4092 non-null   object
#  1   hora                       4092 non-null   object
#  2   natureza_acidente          4091 non-null   object
#  3   situacao                   4091 non-null   object
#  4   bairro                     4058 non-null   object
#  5   endereco                   4079 non-null   object
#  6   numero                     2317 non-null   object
#  7   detalhe_endereco_acidente  1673 non-null   object
#  8   complemento                3614 non-null   object
#  9   bairro_cruzamento          4057 non-null   object
#  10  num_semaforo               1133 non-null   float64
#  11  sentido_via                2845 non-null   object
#  12  tipo                       4092 non-null   object
#  13  descricao                  3988 non-null   object
#  14  auto                       3484 non-null   float64
#  15  moto                       1692 non-null   float64
#  16  ciclom                     19 non-null     float64
#  17  ciclista                   152 non-null    float64
#  18  pedestre                   155 non-null    float64
#  19  onibus                     491 non-null    float64
#  20  caminhao                   295 non-null    float64
#  21  viatura                    72 non-null     float64
#  22  outros                     60 non-null     float64
#  23  vitimas                    4078 non-null   float64
#  24  vitimasfatais              21 non-null     float64
#  25  acidente_verificado        3290 non-null   object
#  26  tempo_clima                3377 non-null   object
#  27  situacao_semaforo          3327 non-null   object
#  28  sinalizacao                3311 non-null   object
#  29  condicao_via               3365 non-null   object
#  30  conservacao_via            3317 non-null   object
#  31  ponto_controle             3142 non-null   object
#  32  situacao_placa             3053 non-null   object
#  33  velocidade_max_via         1096 non-null   object
#  34  mao_direcao                3305 non-null   object
#  35  divisao_via1               3212 non-null   object
#  36  divisao_via2               349 non-null    object
#  37  divisao_via3               66 non-null     object
# dtypes: float64(12), object(26)
# memory usage: 1.2+ MB

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   data                       2380 non-null   object
#  1   hora                       2380 non-null   object
#  2   natureza_acidente          2380 non-null   object
#  3   situacao                   2380 non-null   object
#  4   bairro                     2375 non-null   object
#  5   endereco                   2376 non-null   object
#  6   numero                     1301 non-null   object
#  7   detalhe_endereco_acidente  909 non-null    object
#  8   complemento                2200 non-null   object
#  9   bairro_cruzamento          2375 non-null   object
#  10  num_semaforo               611 non-null    object
#  11  sentido_via                1513 non-null   object
#  12  tipo                       2322 non-null   object
#  13  auto                       2380 non-null   int64
#  14  moto                       2380 non-null   int64
#  15  ciclom                     2380 non-null   int64
#  16  ciclista                   2380 non-null   int64
#  17  pedestre                   2380 non-null   int64
#  18  onibus                     2380 non-null   int64
#  19  caminhao                   2380 non-null   int64
#  20  viatura                    2380 non-null   int64
#  21  outros                     2380 non-null   int64
#  22  vitimas                    2380 non-null   int64
#  23  vitimasfatais              2380 non-null   int64
#  24  acidente_verificado        1785 non-null   object
#  25  tempo_clima                1796 non-null   object
#  26  situacao_semaforo          1778 non-null   object
#  27  sinalizacao                1754 non-null   object
#  28  condicao_via               1792 non-null   object
#  29  conservacao_via            1764 non-null   object
#  30  ponto_controle             1704 non-null   object
#  31  situacao_placa             1669 non-null   object
#  32  velocidade_max_via         655 non-null    object
#  33  mao_direcao                1742 non-null   object
#  34  divisao_via1               1701 non-null   object
#  35  divisao_via2               192 non-null    object
#  36  divisao_via3               32 non-null     object
# dtypes: int64(11), object(26)
# memory usage: 688.1+ KB

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2669 entries, 0 to 2668
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Protocolo                  2669 non-null   object
#  1   data                       2669 non-null   object
#  2   hora                       0 non-null      float64
#  3   natureza                   2669 non-null   object
#  4   situacao                   2669 non-null   object
#  5   bairro                     2659 non-null   object
#  6   endereco                   2663 non-null   object
#  7   numero                     1501 non-null   object
#  8   detalhe_endereco_acidente  1013 non-null   object
#  9   complemento                2514 non-null   object
#  10  bairro_cruzamento          2659 non-null   object
#  11  num_semaforo               631 non-null    object
#  12  sentido_via                1552 non-null   object
#  13  tipo                       2563 non-null   object
#  14  auto                       2669 non-null   object
#  15  moto                       2669 non-null   object
#  16  ciclom                     2669 non-null   object
#  17  ciclista                   2669 non-null   object
#  18  pedestre                   2669 non-null   object
#  19  onibus                     2669 non-null   object
#  20  caminhao                   2669 non-null   object
#  21  viatura                    2669 non-null   object
#  22  outros                     2669 non-null   object
#  23  vitimas                    2669 non-null   object
#  24  vitimasfatais              2669 non-null   object
#  25  acidente_verificado        2092 non-null   object
#  26  tempo_clima                2111 non-null   object
#  27  situacao_semaforo          2090 non-null   object
#  28  sinalizacao                2079 non-null   object
#  29  condicao_via               2103 non-null   object
#  30  conservacao_via            2088 non-null   object
#  31  ponto_controle             2002 non-null   object
#  32  situacao_placa             1979 non-null   object
#  33  velocidade_max_via         767 non-null    object
#  34  mao_direcao                2059 non-null   object
#  35  divisao_via1               2026 non-null   object
#  36  divisao_via2               210 non-null    object
#  37  divisao_via3               31 non-null     object
# dtypes: float64(1), object(37)
# memory usage: 792.5+ KB
