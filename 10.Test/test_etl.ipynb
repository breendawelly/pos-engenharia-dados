# %%
#Principais Imports
import pandas as pd

# %%
#leitura das bases

df_2018 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/2485590a-3b35-4ad0-b955-8dfc36b61021/download/acidentes_2018.csv", delimiter=";")
df_2019 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/3531bafe-d47d-415e-b154-a881081ac76c/download/acidentes-2019.csv", delimiter=";")
df_2020 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/fc1c8460-0406-4fff-b51a-e79205d1f1ab/download/acidentes_2020-novo.csv", delimiter=";")
df_2021 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/2caa8f41-ccd9-4ea5-906d-f66017d6e107/download/acidentes2021.csv", delimiter=";")
df_2022 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/971e0228-fa9c-4a42-b360-c842b29d2f56/download/acidentes2022.csv", delimiter=";")

# %%
#concatenação das bases
df_final =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022], ignore_index =True)

# %%
df_final
# Out:
#              DATA      hora natureza_acidente    situacao            bairro  \
# 0      2018-01-01  00:01:00        COM VÍTIMA  FINALIZADA          SÃO JOSÉ
# 1      2018-01-01  02:45:00        SEM VÍTIMA   CANCELADA          CORDEIRO
# 2      2018-01-01  03:33:00        SEM VÍTIMA   CANCELADA        BOA VIAGEM
# 3      2018-01-01  07:13:00        SEM VÍTIMA  FINALIZADA  BAIRRO DO RECIFE
# 4      2018-01-01  07:50:00        SEM VÍTIMA  FINALIZADA      CASA AMARELA
# ...           ...       ...               ...         ...               ...
# 32609         NaN       NaN               NaN  FINALIZADA             DERBY
# 32610         NaN       NaN               NaN  FINALIZADA         BOA VISTA
# 32611         NaN       NaN               NaN  FINALIZADA           CABANGA
# 32612         NaN       NaN               NaN  FINALIZADA           CABANGA
# 32613         NaN       NaN               NaN   CANCELADA     LINHA DO TIRO
#
#                                endereco  numero detalhe_endereco_acidente  \
# 0           AV ENGENHEIRO JOSE ESTELITA     NaN                       NaN
# 1                            AV CAXANGA     NaN                       NaN
# 2                 AV CONSELHEIRO AGUIAR     NaN                       NaN
# 3                     AV ALFREDO LISBOA     NaN                       NaN
# 4                       RUA PADRE LEMOS     767                       NaN
# ...                                 ...     ...                       ...
# 32609      PRC PROFESSOR AGEU MAGALHAES     NaN                       NaN
# 32610  AV GOVERNADOR AGAMENON MAGALHAES  2997,0      RUA DR LEOPOLDO LINS
# 32611             AV SATURNINO DE BRITO   401,0                       NaN
# 32612            VIADUTO CAPITAO TEMUDO     NaN                       NaN
# 32613                  RUA ALTO DO TIRO     NaN                       NaN
#
#                                              complemento  \
# 0                        EM FRENTE AO CAIS JOSE ESTELITA
# 1      PROX DO GALETOS, EM FRENTE AO PARQUE DE EXPOSI...
# 2            PROX DO BANCO DO BRASIL, PROX DO BANCO ITAÚ
# 3      PROX AO POSTO DE GASOLINA BR AO LADO DO ARMAZE...
# 4                           EM FRENTE AO POSTO PETROBRAS
# ...                                                  ...
# 32609                     EM FRENTE AO  QUARTEL DO DERBY
# 32610                EM FRENTE A CAIXA ENONOMICA FEDERAL
# 32611            EM FRENTE A COMPESA/ SENTIDO BOA VIAGEM
# 32612                           PROX AO CABAGA IATE CLUB
# 32613                              AO DO CAMPO DO CAFÉ ,
#
#                endereco_cruzamento  ...     ponto_controle situacao_placa  \
# 0      AV ENGENHEIRO JOSE ESTELITA  ...                NaN            NaN
# 1                       AV CAXANGA  ...                NaN            NaN
# 2            AV CONSELHEIRO AGUIAR  ...                NaN            NaN
# 3                AV ALFREDO LISBOA  ...                NaN            NaN
# 4                  RUA PADRE LEMOS  ...                NaN            NaN
# ...                            ...  ...                ...            ...
# 32609                          NaN  ...  Faixa de pedestre  Não há placas
# 32610                          NaN  ...         Não existe  Não há placas
# 32611                          NaN  ...  Faixa de pedestre           R-19
# 32612                          NaN  ...         Não existe  Não há placas
# 32613                          NaN  ...                NaN            NaN
#
#       velocidade_max_via mao_direcao      divisao_via1 divisao_via2  \
# 0                    NaN         NaN               NaN          NaN
# 1                    NaN         NaN               NaN          NaN
# 2                    NaN         NaN               NaN          NaN
# 3                    NaN         NaN               NaN          NaN
# 4                    NaN         NaN               NaN          NaN
# ...                  ...         ...               ...          ...
# 32609                NaN       Única               NaN          NaN
# 32610                NaN       Única  Canteiro central          NaN
# 32611            60 km/h       Única  Faixa seccionada          NaN
# 32612                NaN       Dupla  Faixa seccionada          NaN
# 32613                NaN         NaN               NaN          NaN
#
#       divisao_via3        data    Protocolo    natureza
# 0              NaN         NaN          NaN         NaN
# 1              NaN         NaN          NaN         NaN
# 2              NaN         NaN          NaN         NaN
# 3              NaN         NaN          NaN         NaN
# 4              NaN         NaN          NaN         NaN
# ...            ...         ...          ...         ...
# 32609          NaN  2022-12-31  202231513,0  COM VÍTIMA
# 32610          NaN  2022-12-31  202231531,0  SEM VÍTIMA
# 32611          NaN  2022-12-31  202231535,0  COM VÍTIMA
# 32612          NaN  2022-12-31  202231553,0  COM VÍTIMA
# 32613          NaN  2022-12-31  202231555,0  SEM VÍTIMA
#
# [32614 rows x 44 columns]

# %%
colunas = df_final.columns.tolist()
print(colunas)
# Out:
# ['DATA', 'hora', 'natureza_acidente', 'situacao', 'bairro', 'endereco', 'numero', 'detalhe_endereco_acidente', 'complemento', 'endereco_cruzamento', 'numero_cruzamento', 'referencia_cruzamento', 'bairro_cruzamento', 'num_semaforo', 'sentido_via', 'tipo', 'descricao', 'auto', 'moto', 'ciclom', 'ciclista', 'pedestre', 'onibus', 'caminhao', 'viatura', 'outros', 'vitimas', 'vitimasfatais', 'acidente_verificado', 'tempo_clima', 'situacao_semaforo', 'sinalizacao', 'condicao_via', 'conservacao_via', 'ponto_controle', 'situacao_placa', 'velocidade_max_via', 'mao_direcao', 'divisao_via1', 'divisao_via2', 'divisao_via3', 'data', 'Protocolo', 'natureza']

# %%
colunas_nomes = pd.DataFrame({'Nomes de Colunas': df_final.columns})
print(colunas_nomes)
# Out:
#              Nomes de Colunas
# 0                        DATA
# 1                        hora
# 2           natureza_acidente
# 3                    situacao
# 4                      bairro
# 5                    endereco
# 6                      numero
# 7   detalhe_endereco_acidente
# 8                 complemento
# 9         endereco_cruzamento
# 10          numero_cruzamento
# 11      referencia_cruzamento
# 12          bairro_cruzamento
# 13               num_semaforo
# 14                sentido_via
# 15                       tipo
# 16                  descricao
# 17                       auto
# 18                       moto
# 19                     ciclom
# 20                   ciclista
# 21                   pedestre
# 22                     onibus
# 23                   caminhao
# 24                    viatura
# 25                     outros
# 26                    vitimas
# 27              vitimasfatais
# 28        acidente_verificado
# 29                tempo_clima
# 30          situacao_semaforo
# 31                sinalizacao
# 32               condicao_via
# 33            conservacao_via
# 34             ponto_controle
# 35             situacao_placa
# 36         velocidade_max_via
# 37                mao_direcao
# 38               divisao_via1
# 39               divisao_via2
# 40               divisao_via3
# 41                       data
# 42                  Protocolo
# 43                   natureza

# %%
info_colunas = pd.DataFrame({'Nome de colunas':df_final.columns, 'Tipos de Dados':df_final.dtypes})
print(info_colunas)
# Out:
#                                      Nome de colunas Tipos de Dados
# DATA                                            DATA         object
# hora                                            hora         object
# natureza_acidente                  natureza_acidente         object
# situacao                                    situacao         object
# bairro                                        bairro         object
# endereco                                    endereco         object
# numero                                        numero         object
# detalhe_endereco_acidente  detalhe_endereco_acidente         object
# complemento                              complemento         object
# endereco_cruzamento              endereco_cruzamento         object
# numero_cruzamento                  numero_cruzamento         object
# referencia_cruzamento          referencia_cruzamento         object
# bairro_cruzamento                  bairro_cruzamento         object
# num_semaforo                            num_semaforo         object
# sentido_via                              sentido_via         object
# tipo                                            tipo         object
# descricao                                  descricao         object
# auto                                            auto         object
# moto                                            moto         object
# ciclom                                        ciclom         object
# ciclista                                    ciclista         object
# pedestre                                    pedestre         object
# onibus                                        onibus         object
# caminhao                                    caminhao         object
# viatura                                      viatura         object
# outros                                        outros         object
# vitimas                                      vitimas         object
# vitimasfatais                          vitimasfatais         object
# acidente_verificado              acidente_verificado         object
# tempo_clima                              tempo_clima         object
# situacao_semaforo                  situacao_semaforo         object
# sinalizacao                              sinalizacao         object
# condicao_via                            condicao_via         object
# conservacao_via                      conservacao_via         object
# ponto_controle                        ponto_controle         object
# situacao_placa                        situacao_placa         object
# velocidade_max_via                velocidade_max_via         object
# mao_direcao                              mao_direcao         object
# divisao_via1                            divisao_via1         object
# divisao_via2                            divisao_via2         object
# divisao_via3                            divisao_via3         object
# data                                            data         object
# Protocolo                                  Protocolo         object
# natureza                                    natureza         object

# %%
num_colunas_2018 = len(df_2018.columns)
print("Número de colunas 2018:", num_colunas_2018)

num_colunas_2019 = len(df_2019.columns)
print("Numero de colunas 2019:", num_colunas_2019)

num_colunas_2020 = len(df_2020.columns)
print("Numero de colunas 2020:", num_colunas_2020)

num_colunas_2021 = len(df_2021.columns)
print("Numero de colunas 2021:", num_colunas_2021)

num_colunas_2022 = len(df_2022.columns)
print("Numero de colunas 2022:", num_colunas_2022)
# Out:
# Número de colunas 2018: 41
# Numero de colunas 2019: 41
# Numero de colunas 2020: 38
# Numero de colunas 2021: 37
# Numero de colunas 2022: 38

# %%
#novos comandos aprendidos 

# Certificar-se de que a pasta existe
os.makedirs(raw_data_folder, exist_ok=True)

import os
current_directory = os.getcwd()
print("Diretório atual:", current_directory)
#isso pra saber em qual diretorio eu estou
