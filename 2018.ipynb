# %%
#Principais Imports
import pandas as pd

# %%
df_2018 = pd.read_csv("http://dados.recife.pe.gov.br/dataset/44087d2d-73b5-4ab3-9bd8-78da7436eed1/resource/2485590a-3b35-4ad0-b955-8dfc36b61021/download/acidentes_2018.csv", delimiter=";")

# %%
df_2018
# Out:
#              DATA      hora natureza_acidente    situacao            bairro  \
# 0      2018-01-01  00:01:00        COM VÍTIMA  FINALIZADA          SÃO JOSÉ
# 1      2018-01-01  02:45:00        SEM VÍTIMA   CANCELADA          CORDEIRO
# 2      2018-01-01  03:33:00        SEM VÍTIMA   CANCELADA        BOA VIAGEM
# 3      2018-01-01  07:13:00        SEM VÍTIMA  FINALIZADA  BAIRRO DO RECIFE
# 4      2018-01-01  07:50:00        SEM VÍTIMA  FINALIZADA      CASA AMARELA
# ...           ...       ...               ...         ...               ...
# 11406  2018-12-31  14:31:00        SEM VÍTIMA  FINALIZADA         PAISSANDU
# 11407  2018-12-31  14:45:00        COM VÍTIMA  FINALIZADA              PINA
# 11408  2018-12-31  14:46:00        SEM VÍTIMA  FINALIZADA          AFOGADOS
# 11409  2018-12-31  20:06:00        SEM VÍTIMA  FINALIZADA           TEJIPIÓ
# 11410  2018-12-31  21:32:00        SEM VÍTIMA   CANCELADA        BOA VIAGEM
#
#                                endereco numero detalhe_endereco_acidente  \
# 0           AV ENGENHEIRO JOSE ESTELITA    NaN                       NaN
# 1                            AV CAXANGA    NaN                       NaN
# 2                 AV CONSELHEIRO AGUIAR    NaN                       NaN
# 3                     AV ALFREDO LISBOA    NaN                       NaN
# 4                       RUA PADRE LEMOS    767                       NaN
# ...                                 ...    ...                       ...
# 11406  AV GOVERNADOR AGAMENON MAGALHAES    NaN             RUA PAISSANDU
# 11407             AV HERCULANO BANDEIRA    NaN                       NaN
# 11408           RUA VINTE E UM DE ABRIL    220                       NaN
# 11409                 AV DR JOSE RUFINO    NaN                       NaN
# 11410              RUA RIBEIRO DE BRITO    NaN        RUA DOS NAVEGANTES
#
#                                              complemento  \
# 0                        EM FRENTE AO CAIS JOSE ESTELITA
# 1      PROX DO GALETOS, EM FRENTE AO PARQUE DE EXPOSI...
# 2            PROX DO BANCO DO BRASIL, PROX DO BANCO ITAÚ
# 3      PROX AO POSTO DE GASOLINA BR AO LADO DO ARMAZE...
# 4                           EM FRENTE AO POSTO PETROBRAS
# ...                                                  ...
# 11406                                                NaN
# 11407                               E/F A IGREJA DO PINA
# 11408                               PROXIMO A MASTER BOI
# 11409                         PRÓXIMO AO MOTEL OLIMPIKUS
# 11410                                POR TRAZ DO HOLIDAY
#
#                     endereco_cruzamento  ...      sinalizacao condicao_via  \
# 0           AV ENGENHEIRO JOSE ESTELITA  ...              NaN          NaN
# 1                            AV CAXANGA  ...              NaN          NaN
# 2                 AV CONSELHEIRO AGUIAR  ...              NaN          NaN
# 3                     AV ALFREDO LISBOA  ...              NaN          NaN
# 4                       RUA PADRE LEMOS  ...              NaN          NaN
# ...                                 ...  ...              ...          ...
# 11406  AV GOVERNADOR AGAMENON MAGALHAES  ...  Perfeito estado         Seca
# 11407             AV HERCULANO BANDEIRA  ...  Perfeito estado         Seca
# 11408           RUA VINTE E UM DE ABRIL  ...       Incompleta         Seca
# 11409                 AV DR JOSE RUFINO  ...              NaN          NaN
# 11410              RUA RIBEIRO DE BRITO  ...              NaN          NaN
#
#        conservacao_via     ponto_controle situacao_placa velocidade_max_via  \
# 0                  NaN                NaN            NaN                NaN
# 1                  NaN                NaN            NaN                NaN
# 2                  NaN                NaN            NaN                NaN
# 3                  NaN                NaN            NaN                NaN
# 4                  NaN                NaN            NaN                NaN
# ...                ...                ...            ...                ...
# 11406  Perfeito estado  Faixa de pedestre           R-6a            60 km/h
# 11407  Perfeito estado  Faixa de pedestre           R-32            60 km/h
# 11408  Perfeito estado             Outros         Outras                NaN
# 11409              NaN         Não existe           R-6a            60 km/h
# 11410              NaN                NaN            NaN                NaN
#
#       mao_direcao      divisao_via1  divisao_via2  divisao_via3
# 0             NaN               NaN           NaN           NaN
# 1             NaN               NaN           NaN           NaN
# 2             NaN               NaN           NaN           NaN
# 3             NaN               NaN           NaN           NaN
# 4             NaN               NaN           NaN           NaN
# ...           ...               ...           ...           ...
# 11406       Dupla  Canteiro central           NaN           NaN
# 11407       Única  Faixa seccionada           NaN           NaN
# 11408       Única        Não existe           NaN           NaN
# 11409       Dupla  Faixa seccionada           NaN           NaN
# 11410         NaN               NaN           NaN           NaN
#
# [11411 rows x 41 columns]

# %%
num_colunas = len(df_2018.columns)
print("Número de colunas 2018:", num_colunas)
# Out:
# Número de colunas 2018: 41

# %%
# Usar o método melt para transformar as colunas em linhas
df_melted = pd.melt(df_2018)
print(df_melted)
# Out:
#             variable       value
# 0               DATA  2018-01-01
# 1               DATA  2018-01-01
# 2               DATA  2018-01-01
# 3               DATA  2018-01-01
# 4               DATA  2018-01-01
# ...              ...         ...
# 467846  divisao_via3         NaN
# 467847  divisao_via3         NaN
# 467848  divisao_via3         NaN
# 467849  divisao_via3         NaN
# 467850  divisao_via3         NaN
#
# [467851 rows x 2 columns]

# %%
# Obter uma lista com os nomes de todas as colunas
lista_colunas = df_2018.columns.tolist()

# Exibir a lista de nomes de colunas
print(lista_colunas)
# Out:
# ['DATA', 'hora', 'natureza_acidente', 'situacao', 'bairro', 'endereco', 'numero', 'detalhe_endereco_acidente', 'complemento', 'endereco_cruzamento', 'numero_cruzamento', 'referencia_cruzamento', 'bairro_cruzamento', 'num_semaforo', 'sentido_via', 'tipo', 'descricao', 'auto', 'moto', 'ciclom', 'ciclista', 'pedestre', 'onibus', 'caminhao', 'viatura', 'outros', 'vitimas', 'vitimasfatais', 'acidente_verificado', 'tempo_clima', 'situacao_semaforo', 'sinalizacao', 'condicao_via', 'conservacao_via', 'ponto_controle', 'situacao_placa', 'velocidade_max_via', 'mao_direcao', 'divisao_via1', 'divisao_via2', 'divisao_via3']

# %%
# Configurar pandas para exibir todas as linhas
pd.set_option('display.max_rows', None)

# Criar um DataFrame com os nomes das colunas
colunas_nomes = pd.DataFrame({'Nomes de Colunas': df_2018.columns})

# Exibir o DataFrame de nomes de colunas
print(colunas_nomes)
# Out:
#              Nomes de Colunas
# 0                        DATA
# 1                        hora
# 2           natureza_acidente
# 3                    situacao
# 4                      bairro
# 5                    endereco
# 6                      numero
# 7   detalhe_endereco_acidente
# 8                 complemento
# 9         endereco_cruzamento
# 10          numero_cruzamento
# 11      referencia_cruzamento
# 12          bairro_cruzamento
# 13               num_semaforo
# 14                sentido_via
# 15                       tipo
# 16                  descricao
# 17                       auto
# 18                       moto
# 19                     ciclom
# 20                   ciclista
# 21                   pedestre
# 22                     onibus
# 23                   caminhao
# 24                    viatura
# 25                     outros
# 26                    vitimas
# 27              vitimasfatais
# 28        acidente_verificado
# 29                tempo_clima
# 30          situacao_semaforo
# 31                sinalizacao
# 32               condicao_via
# 33            conservacao_via
# 34             ponto_controle
# 35             situacao_placa
# 36         velocidade_max_via
# 37                mao_direcao
# 38               divisao_via1
# 39               divisao_via2
# 40               divisao_via3
